# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
from IPython.display import display
import seaborn as sns

# %%
# Segment each controlled trial run

fft = pd.read_csv('data/diego-controlled-runs/grafana_data_export oct_fftcb.csv', sep=';', engine='python', header=1)
fft['Time'] = pd.to_datetime(fft['Time'])
fft.reset_index(inplace=True, drop=True)

figure(figsize=(20, 6), dpi=80)
plt.scatter(x=fft[fft['Series'] == 'CB FFT Band 3'].reset_index().iloc[1890:2800, :].index, 
            y=fft[fft['Series'] == 'CB FFT Band 3'].iloc[1890:2800, :]['Value'], alpha=.7, s=5)
plt.axvline(x=1890, color='red')
plt.axvline(x=2762, color='red')
plt.title('CB FFT Band 3')
plt.ylabel('FFT')
plt.show()

CB_FFT_Band3_B1 = fft[fft['Series'] == 'CB FFT Band 3'].reset_index(drop=True).iloc[1890:2763, :].reset_index(drop=True)
CB_FFT_Band3_B1['Run Code'] = 'B1'
display(CB_FFT_Band3_B1.head())

start, end = 3600, 4550
figure(figsize=(20, 6), dpi=80)
plt.scatter(x=fft[fft['Series'] == 'CB FFT Band 3'].reset_index(drop=True).iloc[start:end, :].index, 
            y=fft[fft['Series'] == 'CB FFT Band 3'].reset_index(drop=True).iloc[start:end, :]['Value'], alpha=.7, s=5)
plt.axvline(x=3618, color='red')
plt.axvline(x=4510, color='red')
plt.ylabel('FFT')
plt.show()

CB_FFT_Band3_B2 = fft[fft['Series'] == 'CB FFT Band 3'].reset_index(drop=True).iloc[3618:4511, :].reset_index(drop=True)
CB_FFT_Band3_B2['Run Code'] = 'B2'
display(CB_FFT_Band3_B2.head())

start, end = 6500, 7500
figure(figsize=(20, 6), dpi=80)
plt.scatter(x=fft[fft['Series'] == 'CB FFT Band 3'].reset_index(drop=True).iloc[start:end, :].index, 
            y=fft[fft['Series'] == 'CB FFT Band 3'].reset_index(drop=True).iloc[start:end, :]['Value'], alpha=.7, s=5)
plt.axvline(x=6590, color='red')
plt.axvline(x=7442, color='red')
plt.ylabel('FFT')
plt.show()

CB_FFT_Band3_B3 = fft[fft['Series'] == 'CB FFT Band 3'].reset_index(drop=True).iloc[6590:7443, :].reset_index(drop=True)
CB_FFT_Band3_B3['Run Code'] = 'B3'
display(CB_FFT_Band3_B3.head())

start, end = 23250, 23500
figure(figsize=(20, 6), dpi=80)
plt.scatter(x=fft[fft['Series'] == 'CB FFT Band 3'].reset_index(drop=True).iloc[start:end, :].index, 
            y=fft[fft['Series'] == 'CB FFT Band 3'].reset_index(drop=True).iloc[start:end, :]['Value'], alpha=.7, s=5)
plt.axvline(x=23292, color='red')
plt.axvline(x=23483, color='red')
plt.ylabel('FFT')
plt.show()

CB_FFT_Band3_A1 = fft[fft['Series'] == 'CB FFT Band 3'].reset_index(drop=True).iloc[23292:23484, :].reset_index(drop=True)
CB_FFT_Band3_A1['Run Code'] = 'A1'
display(CB_FFT_Band3_A1.head())

start, end = 24050, 24805
figure(figsize=(20, 6), dpi=80)
plt.scatter(x=fft[fft['Series'] == 'CB FFT Band 3'].reset_index(drop=True).iloc[start:end, :].index, 
            y=fft[fft['Series'] == 'CB FFT Band 3'].reset_index(drop=True).iloc[start:end, :]['Value'], alpha=.7, s=5)
plt.axvline(x=24075, color='red')
plt.axvline(x=24793, color='red')
plt.ylabel('FFT')
plt.show()

CB_FFT_Band3_A2 = fft[fft['Series'] == 'CB FFT Band 3'].reset_index(drop=True).iloc[24075:24794, :].reset_index(drop=True)
CB_FFT_Band3_A2['Run Code'] = 'A2'
display(CB_FFT_Band3_A2.head())

start, end = 24843, 25400
figure(figsize=(20, 6), dpi=80)
plt.scatter(x=fft[fft['Series'] == 'CB FFT Band 3'].reset_index(drop=True).iloc[start:end, :].index, 
            y=fft[fft['Series'] == 'CB FFT Band 3'].reset_index(drop=True).iloc[start:end, :]['Value'], alpha=.7, s=5)
plt.axvline(x=24842, color='red')
plt.axvline(x=25350, color='red')
plt.ylabel('FFT')
plt.show()

CB_FFT_Band3_A3 = fft[fft['Series'] == 'CB FFT Band 3'].reset_index(drop=True).iloc[24842:25351, :].reset_index(drop=True)
CB_FFT_Band3_A3['Run Code'] = 'A3'
display(CB_FFT_Band3_A3.head())

start, end = 25600, 26300
figure(figsize=(20, 6), dpi=80)
plt.scatter(x=fft[fft['Series'] == 'CB FFT Band 3'].reset_index(drop=True).iloc[start:end, :].index, 
            y=fft[fft['Series'] == 'CB FFT Band 3'].reset_index(drop=True).iloc[start:end, :]['Value'], alpha=.7, s=5)
plt.axvline(x=25657, color='red')
plt.axvline(x=26292, color='red')
plt.ylabel('FFT')
plt.show()

CB_FFT_Band3_A4 = fft[fft['Series'] == 'CB FFT Band 3'].reset_index(drop=True).iloc[25657:26293, :].reset_index(drop=True)
CB_FFT_Band3_A4['Run Code'] = 'A4'
display(CB_FFT_Band3_A4.head())

start, end = 26525, 26700
figure(figsize=(20, 6), dpi=80)
plt.scatter(x=fft[fft['Series'] == 'CB FFT Band 3'].reset_index(drop=True).iloc[start:end, :].index, 
            y=fft[fft['Series'] == 'CB FFT Band 3'].reset_index(drop=True).iloc[start:end, :]['Value'], alpha=.7, s=5)
plt.axvline(x=26545, color='red')
plt.axvline(x=26684, color='red')
plt.ylabel('FFT')
plt.show()

CB_FFT_Band3_A5 = fft[fft['Series'] == 'CB FFT Band 3'].reset_index(drop=True).iloc[26545:26685, :].reset_index(drop=True)
CB_FFT_Band3_A5['Run Code'] = 'A5'
display(CB_FFT_Band3_A5.head())
# Out:
#           Series                      Time     Value Run Code
# 0  CB FFT Band 3 2021-06-21 09:25:10+02:00  0.028637       B1
# 1  CB FFT Band 3 2021-06-21 09:25:20+02:00  0.028637       B1
# 2  CB FFT Band 3 2021-06-21 09:25:20+02:00  0.031780       B1
# 3  CB FFT Band 3 2021-06-21 09:25:20+02:00  0.030772       B1
# 4  CB FFT Band 3 2021-06-21 09:25:20+02:00  0.011761       B1
#           Series                      Time     Value Run Code
# 0  CB FFT Band 3 2021-06-21 09:36:20+02:00  0.012327       B2
# 1  CB FFT Band 3 2021-06-21 09:36:20+02:00  0.011070       B2
# 2  CB FFT Band 3 2021-06-21 09:36:20+02:00  0.072744       B2
# 3  CB FFT Band 3 2021-06-21 09:36:20+02:00  0.085339       B2
# 4  CB FFT Band 3 2021-06-21 09:36:20+02:00  0.047622       B2
#           Series                      Time     Value Run Code
# 0  CB FFT Band 3 2021-06-21 09:55:20+02:00  0.069973       B3
# 1  CB FFT Band 3 2021-06-21 09:55:20+02:00  0.081311       B3
# ...

# %%
# Combine all trials into one DF
domingo_band3 = pd.concat([CB_FFT_Band3_B1, CB_FFT_Band3_B2, CB_FFT_Band3_B3,
                           CB_FFT_Band3_A1, CB_FFT_Band3_A2, CB_FFT_Band3_A3, CB_FFT_Band3_A4, CB_FFT_Band3_A5])
domingo_band3 = domingo_band3.rename(columns={'Value': 'FFT'})
domingo_band3
domingo_band3.to_csv('data/reformated/diego-controlled-oct-fftcb-band3.csv')

# %%
# EDA for september batch

sep = pd.read_excel('data/september-batch/grafana_data_export_OCT104.xlsx')
sep.dropna(inplace=True)
sep['Time'] = pd.to_datetime(sep['Time'])
sept_melt = pd.melt(sep, id_vars='Time', var_name='Band', value_name='FFT')
# display(sept_melt[sept_melt['Band'] == 'CB FFT Band 0'])
# display(sept_melt[sept_melt['Band'] == 'CB FFT Band 7'])
sept_melt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 143528 entries, 0 to 143527
# Data columns (total 3 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    143528 non-null  datetime64[ns, pytz.FixedOffset(120)]
#  1   Band    143528 non-null  object
#  2   FFT     143528 non-null  float64
# dtypes: datetime64[ns, pytz.FixedOffset(120)](1), float64(1), object(1)
# memory usage: 3.3+ MB

# %%
# definitions for the axes
left, width = 0.1, 0.65
bottom, height = 0.1, 0.65
spacing = 0.005

rect_scatter = [left, bottom, width, height]
rect_histy = [left + width + spacing, bottom, 0.1, height]

y_ax_lim = (sept_melt['FFT'].min(), sept_melt['FFT'].max())

def scatter_hist(x, y, rolling_avg, title='placeholder', xlabel='Time', ylabel='FFT',
                 y_ax_lim=None, x_ax_lim=None):

    # start with a square Figure
    fig = plt.figure(figsize=(10, 6), dpi=100)

    ax = fig.add_axes(rect_scatter)
    ax_histy = fig.add_axes(rect_histy, sharey=ax)

    # no labels
    ax_histy.tick_params(axis="y", labelleft=False)

    # the scatter plot:
    ax.scatter(x, y, s=3, alpha=.4)

    # the rolling mean
    ax.plot(rolling_avg, linewidth=2, color='red', label='1-minute rolling mean')
    ax.legend()
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)

    # now determine nice limits by hand:
    binwidth = 0.01
    xymax = max(np.max(x), np.max(y))
    lim = (int(xymax/binwidth) + 1) * binwidth

    bins = np.arange(-lim, lim + binwidth, binwidth)
    ax_histy.hist(y, orientation='horizontal')

    plt.ylim(y_ax_lim)

for band_name in sept_melt['Band'].unique():
    temp_df = sept_melt[sept_melt['Band'] == band_name].reset_index(drop=True)
    temp_df['Rolling Average'] = temp_df['FFT'].rolling(5*20).mean()
    scatter_hist( np.array(temp_df.index), np.array(temp_df['FFT']), np.array(temp_df['Rolling Average']), band_name )
    plt.show()

# %%
oct_overall = pd.read_csv('data/diego-controlled-runs/grafana_data_export oct_overall.csv', sep=';', engine='python', header=1)
oct_overall = oct_overall[oct_overall['Series'] == 'CB Bond Vibration'].reset_index(drop=True)
oct_overall_cb = oct_overall.drop(columns='Series')
oct_overall_cb.head()
oct_overall_cb.to_csv('data/reformated/diego-controlled-oct-overallcb.csv')

# %%
seconds = 60
interval = 40

for run_code in domingo_band3['Run Code'].unique():
    temp_df = domingo_band3[domingo_band3['Run Code'] == run_code].reset_index(drop=True)
    temp_df['Rolling Average'] = temp_df['FFT'].rolling(interval).mean()
    print(temp_df)
    scatter_hist( np.array(temp_df.index), 
                  np.array(temp_df['FFT']), 
                  np.array(temp_df['Rolling Average']), 
                  'Band 3 Run Code ' + run_code)
    plt.show()
# Out:
#             Series                      Time       FFT Run Code  \
# 0    CB FFT Band 3 2021-06-21 09:25:10+02:00  0.028637       B1
# 1    CB FFT Band 3 2021-06-21 09:25:20+02:00  0.028637       B1
# 2    CB FFT Band 3 2021-06-21 09:25:20+02:00  0.031780       B1
# 3    CB FFT Band 3 2021-06-21 09:25:20+02:00  0.030772       B1
# 4    CB FFT Band 3 2021-06-21 09:25:20+02:00  0.011761       B1
# ..             ...                       ...       ...      ...
# 868  CB FFT Band 3 2021-06-21 09:30:40+02:00  0.082205       B1
# 869  CB FFT Band 3 2021-06-21 09:30:40+02:00  0.025702       B1
# 870  CB FFT Band 3 2021-06-21 09:30:40+02:00  0.023746       B1
# 871  CB FFT Band 3 2021-06-21 09:30:40+02:00  0.000814       B1
# 872  CB FFT Band 3 2021-06-21 09:30:40+02:00  0.000730       B1
#
#      Rolling Average
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ..               ...
# 868         0.305438
# ...
